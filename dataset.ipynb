# %%
import pandas as pd

data = pd.read_csv("data/bundesliga.csv")
data = data.drop(data.columns[[0]], axis=1)

data.tail(10)
# Out:
#        matchday        date            home_team final_result  \
# 18598        33  2024-05-12           VfL Bochum          0-5
# 18599        34  2024-05-18     1. FC Heidenheim          4-1
# 18600        34  2024-05-18        Werder Bremen          4-1
# 18601        34  2024-05-18        VfB Stuttgart          4-0
# 18602        34  2024-05-18  Bayer 04 Leverkusen          2-1
# 18603        34  2024-05-18   1. FC Union Berlin          2-1
# 18604        34  2024-05-18  Eintracht Frankfurt          2-2
# 18605        34  2024-05-18  TSG 1899 Hoffenheim          4-2
# 18606        34  2024-05-18        VfL Wolfsburg          1-3
# 18607        34  2024-05-18    Borussia Dortmund          4-0
#
#                   away_team  home_goals  away_goals  winner
# 18598   Bayer 04 Leverkusen           0           5       2
# 18599            1. FC Köln           4           1       0
# 18600            VfL Bochum           4           1       0
# ...
